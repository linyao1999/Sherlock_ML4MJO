# %%
import numpy as np 
import xarray as xr 
import matplotlib.pyplot as plt

# %%
fn1 = '/scratch/users/linyao/ML4MJO/data/rescaled_m10resi_wnx9resi/olr.fltano120.1978to2025based1979to2001.nc'

ds1 = xr.open_dataarray(fn1).sel(time='2016-01-01')

# %%
fig, ax = plt.subplots(1,1, figsize=(16,16*21/180))
vmax = np.max(np.abs(ds1))
plt.contourf(ds1 / vmax, cmap='RdBu_r', levels=np.linspace(-1,1,11))

# %%
ds2[-1].plot()

# %%
(ds1[-1] - ds2[-1]).plot()
