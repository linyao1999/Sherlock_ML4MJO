# %%
import numpy as np 
import xarray as xr 
import matplotlib.pyplot as plt

# %%
fn1 = '/scratch/users/linyao/ML4MJO/data/rescaled_m10all_wnx9all/olr.fltano120.1978to2025based1979to2001.nc'
fn2 = '/scratch/users/linyao/ML4MJO/data/rescaled_m10all_wnx9all/olr.fltano120.noaa.2x2.1979to2022based1979to2001.nc'

fn1 = '/scratch/users/linyao/ML4MJO/data/rescaled_m10resi_wnx9resi/olr.fltano120.1978to2025based1979to2001.nc'
fn2 = '/scratch/users/linyao/ML4MJO/data/rescaled_m10resi_wnx9resi/olr.fltano120.noaa.2x2.1979to2022based1979to2001.nc'

ds1 = xr.open_dataarray(fn1)
ds2 = xr.open_dataarray(fn2)

# %%
ds1[-1].plot()

# %%
ds2[-1].plot()

# %%
(ds1[-1] - ds2[-1]).plot()
