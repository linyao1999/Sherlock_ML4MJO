# %%
import numpy as np 
fn = '/scratch/users/linyao/ML4MJO/scripts/outputs/metrics/era5_BEST_UNet_A_RMM_lead0/metrics_era5_BEST_UNet_A_RMM_lead0_t1_val.npz'
ds = np.load(fn)

# %%
ds
# Out:
# NpzFile '/scratch/users/linyao/ML4MJO/scripts/outputs/metrics/era5_BEST_UNet_A_RMM_lead0/metrics_era5_BEST_UNet_A_RMM_lead0_t1_val.npz' with keys: ind_bcc, ind_rmse, ens_bcc, ens_rmse, lead...

# %%
ds['ens_bcc']
# Out:
# array(0.9982686, dtype=float32)
