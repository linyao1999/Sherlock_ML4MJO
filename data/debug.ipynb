# %%
import numpy as np 
import xarray as xr 
import matplotlib.pyplot as plt

# %%
fn = '/scratch/users/linyao/ML4MJO/data/rescaled_m10resi_wnx9resi/olr.fltano120.1978to2025based1979to2001.nc'
ds = xr.open_dataset(fn)['olr']

# %%
fn2 = '/scratch/users/linyao/ML4MJO/data/unscaled_m10resi_wnx9resi/olr.fltano120.1978to2025based1979to2001.nc'
ds2 = xr.open_dataset(fn2)['olr']

# %%
ds[0].plot()

# %%
ds2[0].plot()
